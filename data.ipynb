# %%
import numpy as np
import pandas as pd

# %%
## define directory
data_directory = 'data/'
genera_survivail_information_path = 'TCGA-BRCA.survival.tsv'
detail_survivail_information_path = 'survival-BRCA_survival.txt'
detail_phenotype_information_path = 'TCGA-BRCA.GDC_phenotype.tsv'

## load all necessary data
general_survival_information = pd.read_csv(data_directory + genera_survivail_information_path, sep='\t', header=0)
detail_survivail_information = pd.read_csv(data_directory + detail_survivail_information_path, sep='\t', header=0)

# %%
general_survival_information
# Out:
#                 sample  OS      _PATIENT  OS.time
# 0     TCGA-C8-A275-01A   0  TCGA-C8-A275        1
# 1     TCGA-BH-A1F8-11B   1  TCGA-BH-A1F8        1
# 2     TCGA-BH-A1F8-01A   1  TCGA-BH-A1F8        1
# 3     TCGA-AC-A7VC-01A   0  TCGA-AC-A7VC        1
# 4     TCGA-AN-A0AM-01A   0  TCGA-AN-A0AM        5
# ...                ...  ..           ...      ...
# 1255  TCGA-B6-A0RE-01A   0  TCGA-B6-A0RE     7777
# 1256  TCGA-B6-A0RN-01A   0  TCGA-B6-A0RN     8008
# 1257  TCGA-B6-A0IA-01A   0  TCGA-B6-A0IA     8391
# 1258  TCGA-B6-A0I5-01A   0  TCGA-B6-A0I5     8556
# 1259  TCGA-B6-A0RU-01A   0  TCGA-B6-A0RU     8605
#
# [1260 rows x 4 columns]

# %%
len(set(detail_survivail_information['_PATIENT']))
# Out:
# 1097

# %%
## check correctness of the duplicated information
## check on the general one
patient_id = general_survival_information['_PATIENT']
duplicated_survival_information = general_survival_information[patient_id.isin(patient_id[patient_id.duplicated()])]

print('General cases:')
duplicated_patient_list = set(duplicated_survival_information['_PATIENT'])
all_correct = True
error_patient_list = []
for patient in duplicated_patient_list:
    current_information = duplicated_survival_information.loc[duplicated_survival_information['_PATIENT'].isin([patient]),]
    if not np.all(current_information['OS.time'].eq(current_information['OS.time'].to_list()[0])):
        error_patient_list.append(patient)
        all_correct = False

if all_correct:
    print('Correct!')
else:
    print('Error! Patient list:')
    print(error_patient_list)
        
## check on the detailed one
patient_id = detail_survivail_information['_PATIENT']
duplicated_survival_information = detail_survivail_information[patient_id.isin(patient_id[patient_id.duplicated()])]

print('Detailed cases:')
duplicated_patient_list = set(duplicated_survival_information['_PATIENT'])
all_correct = True
for patient in duplicated_patient_list:
    current_information = duplicated_survival_information.loc[duplicated_survival_information['_PATIENT'].isin([patient]),]
    if not np.all(current_information['OS.time'].eq(current_information['OS.time'].to_list()[0])):
        error_patient_list.append(patient)
        all_correct = False
        
if all_correct:
    print('Correct!')
else:
    print('Error! Patient list:')
    print(error_patient_list)
# Out:
# General cases:
# Correct!
# Detailed cases:
# Correct!

# %%
## obtain only unique patient information
detail_survivail_information = detail_survivail_information.drop_duplicates(subset=['_PATIENT'])
detail_survivail_information.index = range(detail_survivail_information.shape[0])

# %%
detail_survivail_information.agg({"OS.time": ["min", "max", "median", "skew"],"DSS.time": ["min", "max", "median", "mean"],"DFI.time": ["min", "max", "median", "mean"],"PFI.time": ["min", "max", "median", "mean"]})
# Out:
#             OS.time    DSS.time     DFI.time     PFI.time
# min        0.000000     0.00000     0.000000     0.000000
# max     8605.000000  8605.00000  8556.000000  8556.000000
# median   843.000000   843.00000   763.500000   773.000000
# skew       2.212804         NaN          NaN          NaN
# mean            NaN  1245.64781  1159.317227  1157.697993

# %%
print(detail_survivail_information[detail_survivail_information['OS.time'].isna()])
print(detail_survivail_information[detail_survivail_information['DSS.time'].isna()])
print(detail_survivail_information[detail_survivail_information['DFI.time'].isna()])
print(detail_survivail_information[detail_survivail_information['PFI.time'].isna()])
# Out:
#                sample      _PATIENT  OS  OS.time  DSS  DSS.time  DFI  \
# 1058  TCGA-OL-A66H-01  TCGA-OL-A66H   0      NaN  0.0       NaN  0.0
#
#       DFI.time  PFI  PFI.time Redaction
# 1058       NaN    0       NaN       NaN
#                sample      _PATIENT  OS  OS.time  DSS  DSS.time  DFI  \
# 1058  TCGA-OL-A66H-01  TCGA-OL-A66H   0      NaN  0.0       NaN  0.0
#
#       DFI.time  PFI  PFI.time Redaction
# 1058       NaN    0       NaN       NaN
#                sample      _PATIENT  OS  OS.time  DSS  DSS.time  DFI  \
# 3     TCGA-3C-AALK-01  TCGA-3C-AALK   0   1448.0  0.0    1448.0  NaN
# 5     TCGA-5L-AAT0-01  TCGA-5L-AAT0   0   1477.0  0.0    1477.0  NaN
# 6     TCGA-5L-AAT1-01  TCGA-5L-AAT1   0   1471.0  0.0    1471.0  NaN
# 7     TCGA-5T-A9QA-01  TCGA-5T-A9QA   0    303.0  0.0     303.0  NaN
# 16    TCGA-A1-A0SK-01  TCGA-A1-A0SK   1    967.0  1.0     967.0  NaN
# ...               ...           ...  ..      ...  ...       ...  ...
# 1075  TCGA-PL-A8LY-01  TCGA-PL-A8LY   0      8.0  0.0       8.0  NaN
# 1076  TCGA-PL-A8LZ-01  TCGA-PL-A8LZ   0    302.0  0.0     302.0  NaN
# 1087  TCGA-UL-AAZ6-01  TCGA-UL-AAZ6   0    518.0  0.0     518.0  NaN
# 1088  TCGA-UU-A93S-01  TCGA-UU-A93S   1    116.0  1.0     116.0  NaN
# 1095  TCGA-Z7-A8R5-01  TCGA-Z7-A8R5   0   3287.0  0.0    3287.0  NaN
#
#       DFI.time  PFI  PFI.time Redaction
# 3          NaN    0    1448.0       NaN
# 5          NaN    0    1477.0       NaN
# 6          NaN    0    1471.0       NaN
# 7          NaN    0     303.0       NaN
# 16         NaN    1     967.0       NaN
# ...        ...  ...       ...       ...
# 1075       NaN    0       8.0       NaN
# 1076       NaN    0     302.0       NaN
# 1087       NaN    0     518.0       NaN
# 1088       NaN    1     116.0       NaN
# 1095       NaN    1     181.0       NaN
#
# [145 rows x 11 columns]
#                sample      _PATIENT  OS  OS.time  DSS  DSS.time  DFI  \
# 1058  TCGA-OL-A66H-01  TCGA-OL-A66H   0      NaN  0.0       NaN  0.0
#
#       DFI.time  PFI  PFI.time Redaction
# 1058       NaN    0       NaN       NaN

# %% [markdown]
# OD, DSS and PFI only have one entry with NA value, patient 'TCGA-OL-A66H'. DFI has 145 entries with NA values.

# %%
## drop the patient with NA OD, DSS and PFI.
detail_survivail_information = detail_survivail_information.drop([1058])
detail_survivail_information.sort_values(by=['_PATIENT'])
detail_survivail_information.index = range(detail_survivail_information.shape[0])

# %%
## check if all OD and DSS are equal.
counter = 0
for idx,row in detail_survivail_information.iterrows():
    # print(row)
    if row[3] == row[5] and row[2] == row[4]:
        counter += 1
    else:
        print(row)
print(counter)
# Out:
# sample       TCGA-A2-A0CO-01
# _PATIENT        TCGA-A2-A0CO
# OS                         1
# OS.time               3492.0
# DSS                      0.0
# DSS.time              3492.0
# DFI                      NaN
# DFI.time                 NaN
# PFI                        0
# PFI.time              3492.0
# Redaction                NaN
# Name: 35, dtype: object
# sample       TCGA-A2-A0CS-01
# _PATIENT        TCGA-A2-A0CS
# OS                         1
# OS.time               2348.0
# DSS                      0.0
# DSS.time              2348.0
# DFI                      NaN
# DFI.time                 NaN
# PFI                        0
# PFI.time              2348.0
# Redaction                NaN
# Name: 39, dtype: object
# sample       TCGA-A2-A0CU-01
# _PATIENT        TCGA-A2-A0CU
# OS                         1
# OS.time                158.0
# DSS                      0.0
# DSS.time               158.0
# DFI                      NaN
# DFI.time                 NaN
# PFI                        0
# PFI.time               158.0
# Redaction                NaN
# Name: 41, dtype: object
# sample       TCGA-A2-A0YT-01
# _PATIENT        TCGA-A2-A0YT
# OS                         1
# OS.time                723.0
# DSS                      0.0
# DSS.time               723.0
# DFI                      0.0
# DFI.time               723.0
# PFI                        0
# PFI.time               723.0
# Redaction                NaN
# Name: 90, dtype: object
# sample       TCGA-A2-A3XX-01
# _PATIENT        TCGA-A2-A3XX
# OS                         1
# OS.time               1439.0
# DSS                      0.0
# DSS.time              1439.0
# DFI                      0.0
# DFI.time              1439.0
# PFI                        0
# PFI.time              1439.0
# Redaction                NaN
# Name: 113, dtype: object
# sample       TCGA-A8-A06U-01
# _PATIENT        TCGA-A8-A06U
# OS                         1
# OS.time                883.0
# DSS                      0.0
# DSS.time               883.0
# DFI                      0.0
# DFI.time               883.0
# PFI                        0
# PFI.time               883.0
# Redaction                NaN
# Name: 172, dtype: object
# sample       TCGA-A8-A06X-01
# _PATIENT        TCGA-A8-A06X
# OS                         1
# OS.time                943.0
# DSS                      0.0
# DSS.time               943.0
# DFI                      0.0
# DFI.time               943.0
# PFI                        0
# PFI.time               943.0
# Redaction                NaN
# Name: 173, dtype: object
# sample       TCGA-A8-A08L-01
# _PATIENT        TCGA-A8-A08L
# OS                         1
# OS.time                304.0
# DSS                      0.0
# DSS.time               304.0
# DFI                      0.0
# DFI.time               304.0
# PFI                        0
# PFI.time               304.0
# Redaction                NaN
# Name: 208, dtype: object
# sample       TCGA-A8-A09X-01
# _PATIENT        TCGA-A8-A09X
# OS                         1
# OS.time                426.0
# DSS                      NaN
# DSS.time               426.0
# DFI                      NaN
# DFI.time                 NaN
# PFI                        0
# PFI.time               426.0
# Redaction                NaN
# Name: 240, dtype: object
# sample       TCGA-AC-A3EH-01
# _PATIENT        TCGA-AC-A3EH
# OS                         1
# OS.time                197.0
# DSS                      0.0
# DSS.time               197.0
# DFI                      0.0
# DFI.time               197.0
# PFI                        0
# PFI.time               197.0
# Redaction                NaN
# Name: 268, dtype: object
# sample       TCGA-AO-A03O-01
# _PATIENT        TCGA-AO-A03O
# OS                         1
# OS.time               2483.0
# DSS                      0.0
# DSS.time              2483.0
# DFI                      0.0
# DFI.time              2483.0
# PFI                        0
# PFI.time              2483.0
# Redaction                NaN
# Name: 340, dtype: object
# sample       TCGA-AO-A03U-01
# _PATIENT        TCGA-AO-A03U
# OS                         1
# OS.time               1793.0
# DSS                      0.0
# DSS.time              1793.0
# DFI                      0.0
# DFI.time              1793.0
# PFI                        1
# PFI.time              1614.0
# Redaction                NaN
# Name: 344, dtype: object
# sample       TCGA-AQ-A0Y5-01
# _PATIENT        TCGA-AQ-A0Y5
# OS                         1
# OS.time                172.0
# DSS                      0.0
# DSS.time               172.0
# DFI                      0.0
# DFI.time               172.0
# PFI                        0
# PFI.time               172.0
# Redaction                NaN
# Name: 387, dtype: object
# sample       TCGA-AQ-A7U7-01
# _PATIENT        TCGA-AQ-A7U7
# OS                         1
# OS.time                584.0
# DSS                      0.0
# DSS.time               584.0
# DFI                      0.0
# DFI.time               584.0
# PFI                        0
# PFI.time               584.0
# Redaction                NaN
# Name: 392, dtype: object
# sample       TCGA-AR-A0TR-01
# _PATIENT        TCGA-AR-A0TR
# OS                         1
# OS.time                160.0
# DSS                      NaN
# DSS.time               160.0
# DFI                      0.0
# DFI.time               160.0
# PFI                        0
# PFI.time               160.0
# Redaction                NaN
# Name: 395, dtype: object
# sample       TCGA-AR-A0TZ-01
# _PATIENT        TCGA-AR-A0TZ
# OS                         1
# OS.time               3262.0
# DSS                      NaN
# DSS.time              3262.0
# DFI                      1.0
# DFI.time              1313.0
# PFI                        1
# PFI.time              1313.0
# Redaction                NaN
# Name: 403, dtype: object
# sample       TCGA-AR-A1AT-01
# _PATIENT        TCGA-AR-A1AT
# OS                         1
# OS.time               1272.0
# DSS                      NaN
# DSS.time              1272.0
# DFI                      0.0
# DFI.time              1272.0
# PFI                        0
# PFI.time              1272.0
# Redaction                NaN
# Name: 421, dtype: object
# sample       TCGA-AR-A256-01
# _PATIENT        TCGA-AR-A256
# OS                         1
# OS.time               2854.0
# DSS                      NaN
# DSS.time              2854.0
# DFI                      1.0
# DFI.time              1640.0
# PFI                        1
# PFI.time              1640.0
# Redaction                NaN
# Name: 448, dtype: object
# sample       TCGA-AR-A2LH-01
# _PATIENT        TCGA-AR-A2LH
# OS                         1
# OS.time                616.0
# DSS                      NaN
# DSS.time               616.0
# DFI                      1.0
# DFI.time               434.0
# PFI                        1
# PFI.time               434.0
# Redaction                NaN
# Name: 450, dtype: object
# sample       TCGA-AR-A2LK-01
# _PATIENT        TCGA-AR-A2LK
# OS                         1
# OS.time               1649.0
# DSS                      NaN
# DSS.time              1649.0
# DFI                      1.0
# DFI.time              1304.0
# PFI                        1
# PFI.time              1304.0
# Redaction                NaN
# Name: 452, dtype: object
# sample       TCGA-B6-A0I1-01
# _PATIENT        TCGA-B6-A0I1
# OS                         1
# OS.time               2361.0
# DSS                      0.0
# DSS.time              2361.0
# DFI                      1.0
# DFI.time              1120.0
# PFI                        1
# PFI.time              1120.0
# Redaction                NaN
# Name: 463, dtype: object
# sample       TCGA-B6-A0IC-01
# _PATIENT        TCGA-B6-A0IC
# OS                         1
# OS.time               1542.0
# DSS                      0.0
# DSS.time              1542.0
# DFI                      0.0
# DFI.time              1542.0
# PFI                        0
# PFI.time              1542.0
# Redaction                NaN
# Name: 471, dtype: object
# sample       TCGA-B6-A0IH-01
# _PATIENT        TCGA-B6-A0IH
# OS                         1
# OS.time               3418.0
# DSS                      NaN
# DSS.time              3418.0
# DFI                      0.0
# DFI.time              3418.0
# PFI                        0
# PFI.time              3418.0
# Redaction                NaN
# Name: 474, dtype: object
# sample       TCGA-B6-A0IM-01
# _PATIENT        TCGA-B6-A0IM
# OS                         1
# OS.time               3873.0
# DSS                      0.0
# DSS.time              3873.0
# DFI                      0.0
# DFI.time              3873.0
# PFI                        0
# PFI.time              3873.0
# Redaction                NaN
# Name: 477, dtype: object
# sample       TCGA-B6-A0IP-01
# _PATIENT        TCGA-B6-A0IP
# OS                         1
# OS.time               3926.0
# DSS                      0.0
# DSS.time              3926.0
# DFI                      0.0
# DFI.time              3926.0
# PFI                        0
# PFI.time              3926.0
# Redaction                NaN
# Name: 480, dtype: object
# sample       TCGA-B6-A0RH-01
# _PATIENT        TCGA-B6-A0RH
# OS                         1
# OS.time               6456.0
# DSS                      0.0
# DSS.time              6456.0
# DFI                      1.0
# DFI.time              2165.0
# PFI                        1
# PFI.time              2165.0
# Redaction                NaN
# Name: 484, dtype: object
# sample       TCGA-B6-A0RL-01
# _PATIENT        TCGA-B6-A0RL
# OS                         1
# OS.time               2469.0
# DSS                      0.0
# DSS.time              2469.0
# DFI                      0.0
# DFI.time              2469.0
# PFI                        0
# PFI.time              2469.0
# Redaction                NaN
# Name: 486, dtype: object
# sample       TCGA-B6-A0RM-01
# _PATIENT        TCGA-B6-A0RM
# OS                         1
# OS.time               2373.0
# DSS                      0.0
# DSS.time              2373.0
# DFI                      NaN
# DFI.time                 NaN
# PFI                        0
# PFI.time              2373.0
# Redaction                NaN
# Name: 487, dtype: object
# sample       TCGA-B6-A0RQ-01
# _PATIENT        TCGA-B6-A0RQ
# OS                         1
# OS.time               4267.0
# DSS                      0.0
# DSS.time              4267.0
# DFI                      0.0
# DFI.time              4267.0
# PFI                        0
# PFI.time              4267.0
# Redaction                NaN
# Name: 491, dtype: object
# sample       TCGA-B6-A0WS-01
# _PATIENT        TCGA-B6-A0WS
# OS                         1
# OS.time               2965.0
# DSS                      0.0
# DSS.time              2965.0
# DFI                      NaN
# DFI.time                 NaN
# PFI                        0
# PFI.time              2965.0
# Redaction                NaN
# Name: 496, dtype: object
# sample       TCGA-B6-A0WV-01
# _PATIENT        TCGA-B6-A0WV
# OS                         1
# OS.time               2417.0
# DSS                      0.0
# DSS.time              2417.0
# DFI                      0.0
# DFI.time              2417.0
# PFI                        0
# PFI.time              2417.0
# Redaction                NaN
# Name: 498, dtype: object
# sample       TCGA-B6-A0X0-01
# _PATIENT        TCGA-B6-A0X0
# OS                         1
# OS.time               3945.0
# DSS                      NaN
# DSS.time              3945.0
# DFI                      0.0
# DFI.time              3945.0
# PFI                        0
# PFI.time              3945.0
# Redaction                NaN
# Name: 503, dtype: object
# sample       TCGA-B6-A0X1-01
# _PATIENT        TCGA-B6-A0X1
# OS                         1
# OS.time               7455.0
# DSS                      0.0
# DSS.time              7455.0
# DFI                      1.0
# DFI.time               490.0
# PFI                        1
# PFI.time               490.0
# Redaction                NaN
# Name: 504, dtype: object
# sample       TCGA-B6-A0X7-01
# _PATIENT        TCGA-B6-A0X7
# OS                         1
# OS.time               1781.0
# DSS                      0.0
# DSS.time              1781.0
# DFI                      NaN
# DFI.time                 NaN
# PFI                        1
# PFI.time              1104.0
# Redaction                NaN
# Name: 507, dtype: object
# sample       TCGA-BH-A0BF-01
# _PATIENT        TCGA-BH-A0BF
# OS                         1
# OS.time               1324.0
# DSS                      0.0
# DSS.time              1324.0
# DFI                      0.0
# DFI.time              1324.0
# PFI                        0
# PFI.time              1324.0
# Redaction                NaN
# Name: 538, dtype: object
# sample       TCGA-BH-A0BP-01
# _PATIENT        TCGA-BH-A0BP
# OS                         1
# OS.time               2296.0
# DSS                      0.0
# DSS.time              2296.0
# DFI                      0.0
# DFI.time              2296.0
# PFI                        0
# PFI.time              2296.0
# Redaction                NaN
# Name: 544, dtype: object
# sample       TCGA-BH-A0EA-01
# _PATIENT        TCGA-BH-A0EA
# OS                         1
# OS.time                991.0
# DSS                      0.0
# DSS.time               991.0
# DFI                      0.0
# DFI.time               991.0
# PFI                        0
# PFI.time               991.0
# Redaction                NaN
# Name: 577, dtype: object
# sample       TCGA-BH-A18L-01
# _PATIENT        TCGA-BH-A18L
# OS                         1
# OS.time                811.0
# DSS                      NaN
# DSS.time               811.0
# DFI                      0.0
# DFI.time               811.0
# PFI                        0
# PFI.time               811.0
# Redaction                NaN
# Name: 615, dtype: object
# sample       TCGA-BH-A18M-01
# _PATIENT        TCGA-BH-A18M
# OS                         1
# OS.time               2207.0
# DSS                      NaN
# DSS.time              2207.0
# DFI                      0.0
# DFI.time              2207.0
# PFI                        0
# PFI.time              2207.0
# Redaction                NaN
# Name: 616, dtype: object
# sample       TCGA-BH-A18N-01
# _PATIENT        TCGA-BH-A18N
# OS                         1
# OS.time               1148.0
# DSS                      NaN
# DSS.time              1148.0
# DFI                      0.0
# DFI.time              1148.0
# PFI                        0
# PFI.time              1148.0
# Redaction                NaN
# Name: 617, dtype: object
# sample       TCGA-BH-A18Q-01
# _PATIENT        TCGA-BH-A18Q
# OS                         1
# OS.time               1692.0
# DSS                      NaN
# DSS.time              1692.0
# DFI                      0.0
# DFI.time              1692.0
# PFI                        0
# PFI.time              1692.0
# Redaction                NaN
# Name: 619, dtype: object
# sample       TCGA-BH-A18R-01
# _PATIENT        TCGA-BH-A18R
# OS                         1
# OS.time               1142.0
# DSS                      0.0
# DSS.time              1142.0
# DFI                      0.0
# DFI.time              1142.0
# PFI                        0
# PFI.time              1142.0
# Redaction                NaN
# Name: 620, dtype: object
# sample       TCGA-BH-A18S-01
# _PATIENT        TCGA-BH-A18S
# OS                         1
# OS.time               2009.0
# DSS                      0.0
# DSS.time              2009.0
# DFI                      0.0
# DFI.time              2009.0
# PFI                        0
# PFI.time              2009.0
# Redaction                NaN
# Name: 621, dtype: object
# sample       TCGA-BH-A18U-01
# _PATIENT        TCGA-BH-A18U
# OS                         1
# OS.time               1563.0
# DSS                      0.0
# DSS.time              1563.0
# DFI                      0.0
# DFI.time              1563.0
# PFI                        0
# PFI.time              1563.0
# Redaction                NaN
# Name: 623, dtype: object
# sample       TCGA-BH-A18V-06
# _PATIENT        TCGA-BH-A18V
# OS                         1
# OS.time               1556.0
# DSS                      NaN
# DSS.time              1556.0
# DFI                      0.0
# DFI.time              1556.0
# PFI                        0
# PFI.time              1556.0
# Redaction                NaN
# Name: 624, dtype: object
# sample       TCGA-BH-A1EN-01
# _PATIENT        TCGA-BH-A1EN
# OS                         1
# OS.time               2127.0
# DSS                      0.0
# DSS.time              2127.0
# DFI                      0.0
# DFI.time              2127.0
# PFI                        0
# PFI.time              2127.0
# Redaction                NaN
# Name: 625, dtype: object
# sample       TCGA-BH-A1EO-01
# _PATIENT        TCGA-BH-A1EO
# OS                         1
# OS.time               2798.0
# DSS                      0.0
# DSS.time              2798.0
# DFI                      NaN
# DFI.time                 NaN
# PFI                        0
# PFI.time              2798.0
# Redaction                NaN
# Name: 626, dtype: object
# sample       TCGA-BH-A1ET-01
# _PATIENT        TCGA-BH-A1ET
# OS                         1
# OS.time               2520.0
# DSS                      0.0
# DSS.time              2520.0
# DFI                      NaN
# DFI.time                 NaN
# PFI                        0
# PFI.time              2520.0
# Redaction                NaN
# Name: 628, dtype: object
# sample       TCGA-BH-A1EU-01
# _PATIENT        TCGA-BH-A1EU
# OS                         1
# OS.time               1286.0
# DSS                      0.0
# DSS.time              1286.0
# DFI                      NaN
# DFI.time                 NaN
# PFI                        0
# PFI.time              1286.0
# Redaction                NaN
# Name: 629, dtype: object
# sample       TCGA-BH-A1F2-01
# _PATIENT        TCGA-BH-A1F2
# OS                         1
# OS.time                959.0
# DSS                      0.0
# DSS.time               959.0
# DFI                      NaN
# DFI.time                 NaN
# PFI                        0
# PFI.time               959.0
# Redaction                NaN
# Name: 635, dtype: object
# sample       TCGA-BH-A1F5-01
# _PATIENT        TCGA-BH-A1F5
# OS                         1
# OS.time               2712.0
# DSS                      0.0
# DSS.time              2712.0
# DFI                      NaN
# DFI.time                 NaN
# PFI                        0
# PFI.time              2712.0
# Redaction                NaN
# Name: 636, dtype: object
# sample       TCGA-BH-A1F6-01
# _PATIENT        TCGA-BH-A1F6
# OS                         1
# OS.time               2965.0
# DSS                      NaN
# DSS.time              2965.0
# DFI                      NaN
# DFI.time                 NaN
# PFI                        0
# PFI.time              2965.0
# Redaction                NaN
# Name: 637, dtype: object
# sample       TCGA-BH-A1FC-01
# _PATIENT        TCGA-BH-A1FC
# OS                         1
# OS.time               3472.0
# DSS                      0.0
# DSS.time              3472.0
# DFI                      NaN
# DFI.time                 NaN
# PFI                        0
# PFI.time              3472.0
# Redaction                NaN
# Name: 640, dtype: object
# sample       TCGA-BH-A1FG-01
# _PATIENT        TCGA-BH-A1FG
# OS                         1
# OS.time               3736.0
# DSS                      NaN
# DSS.time              3736.0
# DFI                      NaN
# DFI.time                 NaN
# PFI                        0
# PFI.time              3736.0
# Redaction                NaN
# Name: 643, dtype: object
# sample       TCGA-BH-A1FJ-01
# _PATIENT        TCGA-BH-A1FJ
# OS                         1
# OS.time               1927.0
# DSS                      NaN
# DSS.time              1927.0
# DFI                      NaN
# DFI.time                 NaN
# PFI                        0
# PFI.time              1927.0
# Redaction                NaN
# Name: 645, dtype: object
# sample       TCGA-BH-A1FM-01
# _PATIENT        TCGA-BH-A1FM
# OS                         1
# OS.time               1388.0
# DSS                      NaN
# DSS.time              1388.0
# DFI                      NaN
# DFI.time                 NaN
# PFI                        0
# PFI.time              1388.0
# Redaction                NaN
# Name: 647, dtype: object
# sample       TCGA-BH-A204-01
# _PATIENT        TCGA-BH-A204
# OS                         1
# OS.time               2534.0
# DSS                      NaN
# DSS.time              2534.0
# DFI                      NaN
# DFI.time                 NaN
# PFI                        0
# PFI.time              2534.0
# Redaction                NaN
# Name: 654, dtype: object
# sample       TCGA-BH-A208-01
# _PATIENT        TCGA-BH-A208
# OS                         1
# OS.time               1759.0
# DSS                      0.0
# DSS.time              1759.0
# DFI                      NaN
# DFI.time                 NaN
# PFI                        0
# PFI.time              1759.0
# Redaction                NaN
# Name: 655, dtype: object
# sample       TCGA-BH-A209-01
# _PATIENT        TCGA-BH-A209
# OS                         1
# OS.time               3959.0
# DSS                      0.0
# DSS.time              3959.0
# DFI                      NaN
# DFI.time                 NaN
# PFI                        0
# PFI.time              3959.0
# Redaction                NaN
# Name: 656, dtype: object
# sample       TCGA-BH-A42T-01
# _PATIENT        TCGA-BH-A42T
# OS                         1
# OS.time                320.0
# DSS                      0.0
# DSS.time               320.0
# DFI                      0.0
# DFI.time               320.0
# PFI                        0
# PFI.time               320.0
# Redaction                NaN
# Name: 660, dtype: object
# sample       TCGA-BH-A8FY-01
# _PATIENT        TCGA-BH-A8FY
# OS                         1
# OS.time                295.0
# DSS                      0.0
# DSS.time               295.0
# DFI                      0.0
# DFI.time               295.0
# PFI                        0
# PFI.time               295.0
# Redaction                NaN
# Name: 667, dtype: object
# sample       TCGA-E2-A15M-01
# _PATIENT        TCGA-E2-A15M
# OS                         1
# OS.time                336.0
# DSS                      0.0
# DSS.time               336.0
# DFI                      0.0
# DFI.time               336.0
# PFI                        0
# PFI.time               336.0
# Redaction                NaN
# Name: 840, dtype: object
# sample       TCGA-E2-A1B4-01
# _PATIENT        TCGA-E2-A1B4
# OS                         1
# OS.time               1004.0
# DSS                      0.0
# DSS.time              1004.0
# DFI                      0.0
# DFI.time              1004.0
# PFI                        0
# PFI.time              1004.0
# Redaction                NaN
# Name: 849, dtype: object
# sample       TCGA-E9-A1NG-01
# _PATIENT        TCGA-E9-A1NG
# OS                         1
# OS.time                786.0
# DSS                      0.0
# DSS.time               786.0
# DFI                      0.0
# DFI.time               786.0
# PFI                        0
# PFI.time               786.0
# Redaction                NaN
# Name: 899, dtype: object
# sample       TCGA-E9-A1RB-01
# _PATIENT        TCGA-E9-A1RB
# OS                         1
# OS.time                976.0
# DSS                      0.0
# DSS.time               976.0
# DFI                      0.0
# DFI.time               976.0
# PFI                        0
# PFI.time               976.0
# Redaction                NaN
# Name: 911, dtype: object
# sample       TCGA-OL-A5D6-01
# _PATIENT        TCGA-OL-A5D6
# OS                         1
# OS.time               1104.0
# DSS                      0.0
# DSS.time              1104.0
# DFI                      0.0
# DFI.time              1104.0
# PFI                        0
# PFI.time              1104.0
# Redaction                NaN
# Name: 1047, dtype: object
# sample       TCGA-OL-A66K-01
# _PATIENT        TCGA-OL-A66K
# OS                         1
# OS.time               1275.0
# DSS                      0.0
# DSS.time              1275.0
# DFI                      0.0
# DFI.time              1275.0
# PFI                        0
# PFI.time              1275.0
# Redaction                NaN
# Name: 1060, dtype: object
# sample       TCGA-PE-A5DC-01
# _PATIENT        TCGA-PE-A5DC
# OS                         1
# OS.time               1430.0
# DSS                      0.0
# DSS.time              1430.0
# DFI                      NaN
# DFI.time                 NaN
# PFI                        0
# PFI.time              1430.0
# Redaction                NaN
# Name: 1069, dtype: object
# 1028

# %% [markdown]
# As all OD and DSS time are equal, we can use either one. We choose DSS.

# %%
detail_survivail_information.drop(['OS.time'], axis=1)
